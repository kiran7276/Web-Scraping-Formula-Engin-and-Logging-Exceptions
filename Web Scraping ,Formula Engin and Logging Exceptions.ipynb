# %% [markdown]
# # WEB SCRAPING

# %%
import pandas as pd
import requests
import pymongo
from bs4 import BeautifulSoup

# %%
#client = pymongo.MongoClient("mongodb+srv://test:test@cluster0.08hmy.mongodb.net/newdatabase?retryWrites=true&w=majority")
#db = client.test

# %%
url = 'https://www.iplt20.com/stats/2021/most-runs'
web_content = requests.get(url).content
soup = BeautifulSoup(web_content, "html.parser")
extract_contents = lambda row: [x.text.replace('\n', '') for x in row]
stats = [] 
all_rows = soup.find_all('tr')
for row in all_rows:
    stat = extract_contents(row.find_all('td')) 
    if len(stat) == 14:
        stats.append(stat)
new_cols = ["POS","PLAYER","Mat","Inns","NO","Runs","HS","Avg","BF","SR","100","50","4s","6s"]
state_data = pd.DataFrame(data = stats, columns = new_cols)
state_data.head(10)
# Out:
#   POS                                             PLAYER  \
# 0   1                              Ruturaj           ...
# 1   2                              Faf               ...
# 2   3                              KL                ...
# 3   4                              Shikhar           ...
# 4   5                              Glenn             ...
# 5   6                              Sanju             ...
# 6   7                              Prithvi           ...
# 7   8                              Shubman           ...
# 8   9                              Mayank            ...
# 9  10                              Rishabh           ...
#
#                                       Mat  \
# 0                      16
# 1                      16
# 2                      13
# 3                      16
# 4                      15
# 5                      14
# 6                      15
# 7                      17
# 8                      12
# 9                      16
#
#                                      Inns  \
# 0                      16
# 1                      16
# 2                      13
# 3                      16
# 4                      14
# 5                      14
# 6                      15
# 7                      17
# 8                      12
# 9                      16
#
#                                       NO  \
# 0                      2
# 1                      2
# 2                      3
# 3                      1
# 4                      2
# 5                      2
# 6                      0
# 7                      0
# 8                      1
# 9                      4
#
#                                       Runs  \
# 0                      635
# 1                      633
# 2                      626
# 3                      587
# 4                      513
# 5                      484
# 6                      479
# 7                      478
# 8                      441
# 9                      419
#
#                                          HS  \
# 0                      101*
# 1                       95*
# 2                       98*
# 3                        92
# 4                        78
# 5                       119
# 6                        82
# 7                        57
# 8                       99*
# 9                       58*
#
#                                          Avg  \
# 0                      45.35
# 1                      45.21
# 2                      62.60
# 3                      39.13
# 4                      42.75
# 5                      40.33
# 6                      31.93
# 7                      28.11
# 8                      40.09
# 9                      34.91
#
#                                         BF  \
# 0                      466
# 1                      458
# 2                      451
# 3                      471
# 4                      356
# 5                      354
# 6                      301
# 7                      402
# 8                      314
# 9                      326
#
#                                            SR  \
# 0                      136.26
# 1                      138.20
# 2                      138.80
# 3                      124.62
# 4                      144.10
# 5                      136.72
# 6                      159.13
# 7                      118.90
# 8                      140.44
# 9                      128.52
#
#                                      100  \
# 0                      1
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# 5                      1
# 6                      0
# 7                      0
# 8                      0
# 9                      0
#
#                                       50  \
# 0                      4
# 1                      6
# 2                      6
# 3                      3
# 4                      6
# 5                      2
# 6                      4
# 7                      3
# 8                      4
# 9                      3
#
#                                        4s  \
# 0                      64
# 1                      60
# 2                      48
# 3                      63
# 4                      48
# 5                      45
# 6                      56
# 7                      50
# 8                      42
# 9                      42
#
#                                        6s
# 0                      23
# 1                      23
# 2                      30
# 3                      16
# 4                      21
# 5                      17
# 6                      18
# 7                      12
# 8                      18
# 9                      10

# %%
state_data.shape
# Out:
# (149, 14)

# %%
state_data.head(10)
# Out:
#   POS                                             PLAYER  \
# 0   1                              Ruturaj           ...
# 1   2                              Faf               ...
# 2   3                              KL                ...
# 3   4                              Shikhar           ...
# 4   5                              Glenn             ...
# 5   6                              Sanju             ...
# 6   7                              Prithvi           ...
# 7   8                              Shubman           ...
# 8   9                              Mayank            ...
# 9  10                              Rishabh           ...
#
#                                       Mat  \
# 0                      16
# 1                      16
# 2                      13
# 3                      16
# 4                      15
# 5                      14
# 6                      15
# 7                      17
# 8                      12
# 9                      16
#
#                                      Inns  \
# 0                      16
# 1                      16
# 2                      13
# 3                      16
# 4                      14
# 5                      14
# 6                      15
# 7                      17
# 8                      12
# 9                      16
#
#                                       NO  \
# 0                      2
# 1                      2
# 2                      3
# 3                      1
# 4                      2
# 5                      2
# 6                      0
# 7                      0
# 8                      1
# 9                      4
#
#                                       Runs  \
# 0                      635
# 1                      633
# 2                      626
# 3                      587
# 4                      513
# 5                      484
# 6                      479
# 7                      478
# 8                      441
# 9                      419
#
#                                          HS  \
# 0                      101*
# 1                       95*
# 2                       98*
# 3                        92
# 4                        78
# 5                       119
# 6                        82
# 7                        57
# 8                       99*
# 9                       58*
#
#                                          Avg  \
# 0                      45.35
# 1                      45.21
# 2                      62.60
# 3                      39.13
# 4                      42.75
# 5                      40.33
# 6                      31.93
# 7                      28.11
# 8                      40.09
# 9                      34.91
#
#                                         BF  \
# 0                      466
# 1                      458
# 2                      451
# 3                      471
# 4                      356
# 5                      354
# 6                      301
# 7                      402
# 8                      314
# 9                      326
#
#                                            SR  \
# 0                      136.26
# 1                      138.20
# 2                      138.80
# 3                      124.62
# 4                      144.10
# 5                      136.72
# 6                      159.13
# 7                      118.90
# 8                      140.44
# 9                      128.52
#
#                                      100  \
# 0                      1
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# 5                      1
# 6                      0
# 7                      0
# 8                      0
# 9                      0
#
#                                       50  \
# 0                      4
# 1                      6
# 2                      6
# 3                      3
# 4                      6
# 5                      2
# 6                      4
# 7                      3
# 8                      4
# 9                      3
#
#                                        4s  \
# 0                      64
# 1                      60
# 2                      48
# 3                      63
# 4                      48
# 5                      45
# 6                      56
# 7                      50
# 8                      42
# 9                      42
#
#                                        6s
# 0                      23
# 1                      23
# 2                      30
# 3                      16
# 4                      21
# 5                      17
# 6                      18
# 7                      12
# 8                      18
# 9                      10

# %%
state_data.describe()
# Out:
#         POS                                             PLAYER  \
# count   149                                                149
# unique  149                                                149
# top       1                              Ruturaj           ...
# freq      1                                                  1
#
#                                           Mat  \
# count                                     149
# unique                                     17
# top                         1
# freq                                       14
#
#                                          Inns  \
# count                                     149
# unique                                     17
# top                         2
# freq                                       24
#
#                                            NO  \
# count                                     149
# unique                                      8
# top                         0
# freq                                       48
#
#                                          Runs  \
# count                                     149
# unique                                     98
# top                         0
# freq                                       10
#
#                                             HS  \
# count                                      149
# unique                                      92
# top                         0*
# freq                                        10
#
#                                           Avg  \
# count                                     149
# unique                                    103
# top                         -
# freq                                       15
#
#                                            BF  \
# count                                     149
# unique                                     97
# top                         4
# freq                                       11
#
#                                               SR  \
# count                                        149
# unique                                       119
# top                         0.00
# freq                                          10
#
#                                           100  \
# count                                     149
# unique                                      2
# top                         0
# freq                                      145
#
#                                            50  \
# count                                     149
# unique                                      6
# top                         0
# freq                                      108
#
#                                            4s  \
# count                                     149
# unique                                     42
# top                         0
# freq                                       38
#
#                                            6s
# count                                     149
# unique                                     23
# top                         0
# freq                                       52

# %%
state_data.isnull().sum()
# Out:
# POS       0
# PLAYER    0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Avg       0
# BF        0
# SR        0
# 100       0
# 50        0
# 4s        0
# 6s        0
# dtype: int64

# %% [markdown]
# # Fromula engin

# %%
import parser
from math import sin


formula2 = input('please enter formula ')
code2 = parser.expr(formula2).compile()
x = int(input('enter value of x '))
y = int(input('enter value of y '))
z = int(input('enter value of z '))
print(formula2)
print('value of x:',x,'value of y:',y,'value of z:',z)
print(eval(code2))
# Out:
# please enter formula x+y+z
# enter value of x 70
# enter value of y 90
# enter value of z 50
# x+y+z
# value of x: 70 value of y: 90 value of z: 50
# 210

# %% [markdown]
# # Logging Exceptions
# Basic programming using error handling i.e. try-except-finally

# %%
try:
    f=open('mynew','w')
    f.write('This is my new file')  
    
except:
    print('There is an error occured while writing a file')

# %%
try:
    f=open('mynew','r')  # error created
    f.write('This is my new file')  
    
except:
    print('There is an error occured while writing a file')
# Out:
# There is an error occured while writing a file

# %%
try:
    f=open('mynew','r')
    f.write('This is my new file')  
    
except Exception as err:
    print(f'There is an error: {err}')
# Out:
# There is an error: not writable

# %%
def int_res():
    
    while True:
        
        try:
            result=int(input("Enter the integer number: "))

        except:
            
            print("Entered value is not a number")
            continue
        
        else:
            
            print("Integer number is provided")
            break

# %%
int_res()
# Out:
# Enter the integer number: 30
# Integer number is provided

# %%
try:
    
    for i in ['a','b','c']:
        print(i**2)

except Exception as err:
    print(f"Occured error is: {err}")
# Out:
# Occured error is: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
try:
    
    x=5
    y=0
    x/y
    
except Exception as e:
    print(f"Error occured is: {e}")
# Out:
# Error occured is: division by zero

# %% [markdown]
# # Basic Programming using logging library

# %%
# importing the module

import logging

try:
    printf("Hello World!")

except Exception as Argument:

    logging.exception("Error occured while printing")
# Out:
# ERROR:root:Error occured while printing
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Local\Temp/ipykernel_5624/3547929390.py", line 6, in <module>
#     printf("Hello World!")
# NameError: name 'printf' is not defined

# %%
# importing the module
import logging

try:
    a=10
    b="C"
    c=a+b

except Exception as err:
   
    # creating/opening a file
    f = open("mynew1.txt", "a")
    
    # writing in the file
    f.write(str(err))
    
    # closing the file
    f.close()

# %%
import logging

logger=logging.getLogger()

try:
    printf("Hello World!!")

except Exception:
    logger.exception("Error occured while ruuning a code")
# Out:
# ERROR:root:Error occured while ruuning a code
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Local\Temp/ipykernel_5624/3966204240.py", line 6, in <module>
#     printf("Hello World!!")
# NameError: name 'printf' is not defined

# %%
import logging

logger=logging.getLogger()

try:
    printf("Hello World!!")

except Exception:
    logger.error("Error occured while ruuning a code")
# Out:
# ERROR:root:Error occured while ruuning a code

# %%
import logging

logger=logging.getLogger()

try:
    printf("Hello World!!")

except Exception:
    logger.error("Error occured while ruuning a code",exc_info=True)
# Out:
# ERROR:root:Error occured while ruuning a code
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Local\Temp/ipykernel_5624/2574216460.py", line 6, in <module>
#     printf("Hello World!!")
# NameError: name 'printf' is not defined

# %%
import logging

logger=logging.getLogger()

try:
    printf("Hello World!!")

except Exception as e:
    logger.error("Error occured while ruuning a code",exc_info=e)
# Out:
# ERROR:root:Error occured while ruuning a code
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Local\Temp/ipykernel_5624/3594270411.py", line 6, in <module>
#     printf("Hello World!!")
# NameError: name 'printf' is not defined

# %% [markdown]
# # Programming using logging library and different level

# %%
#importing module
import logging

def main():
    #Create and configure logger
    logging.basicConfig(filename="practice.log", format='[%(asctime)s] %(levelname)-8s %(name)-12s %(message)s', filemode='a')

    
    #Creating an object
    logger=logging.getLogger('my_logger')

    #Setting the threshold of logger to DEBUG
    logger.setLevel(logging.DEBUG)

    #Test messages
    logger.debug("Harmless debug Message")
    logger.info("Just an information")
    logger.warning("Its a Warning")
    logger.error("Did you try to divide by zero")
    logger.critical("Internet is down")

if __name__ == '__main__':
    main()
# Out:
# DEBUG:my_logger:Harmless debug Message
# INFO:my_logger:Just an information
# WARNING:my_logger:Its a Warning
# ERROR:my_logger:Did you try to divide by zero
# CRITICAL:my_logger:Internet is down

# %%
#importing module
import logging

def Addition():
    n1=5
    n2=10

    Addition=n1+n2

    print(f"Addition is: {Addition}")

    
def main():
    #Create and configure logger
    logging.basicConfig(filename="practice1.log", format='[%(asctime)s] %(levelname)-8s %(name)-12s %(message)s', filemode='a')

    
    #Creating an object
    logger=logging.getLogger('my_logger')

    #Setting the threshold of logger to DEBUG
    logger.setLevel(logging.DEBUG)

    #Test messages
    logger.debug("Harmless debug Message")
    logger.info("Just an information")
    logger.warning("Its a Warning")
    logger.error("Did you try to divide by zero")
    logger.critical("Internet is down")

    Addition()
    
if __name__ == '__main__':
    main()
# Out:
# DEBUG:my_logger:Harmless debug Message
# INFO:my_logger:Just an information
# WARNING:my_logger:Its a Warning
# ERROR:my_logger:Did you try to divide by zero
# CRITICAL:my_logger:Internet is down
# Addition is: 15

# %%
import logging 

def Division_fun(a,b):
    try:
        x=a/b
        return x 
    except:
        logging.error('error',exc_info=True)

# %%
Division_fun(4,2)
# Out:
# 2.0

# %%
Division_fun(4,0)
# Out:
# ERROR:root:error
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Local\Temp/ipykernel_5624/4058996115.py", line 5, in Division_fun
#     x=a/b
# ZeroDivisionError: division by zero
